# %%
#1.Write Function(Originally had a different wording after #1 but I accidentally erased it while fixing the code)

sentence = input("1,2,'a','b',7.6: ")

def stringsplit(text):
    return text.split(",")

def output(input_list):
    result_list = []
    for item in input_list:
        if item == 'a' or item == 'b':
            result_list.append(item)
    return result_list

mylist = [1, 2, 'a', 'b', 7.6]

result = output(mylist) 

print(f"Split string: {result}")
# Out:
# Split string: ['a', 'b']

# %%
#2

#FizzBuzz

#takes in a value and returns all values from 1 to that number. If they are divisible by 3, it returns that number and fizz, if they are divisible by 5, it returns that number and buzz, and if they are divisible by both it returns that number and fizzbuzz.

def fizz_buzz(number: int = 15) -> list:
    """
    Creates a list of numbers from 1 to 'number' with FizzBuzz labels.
    """
    result = []
    
    for i in range(1, number + 1):
        if i % 3 == 0 and i % 5 == 0:
            result.append(f"{i} fizzbuzz")
        elif i % 3 == 0:
            result.append(f"{i} fizz")
        elif i % 5 == 0:
            result.append(f"{i} buzz")
        else:
            result.append(i)
            
    return result

print(fizz_buzz(15))
# Out:
# [1, 2, '3 fizz', 4, '5 buzz', '6 fizz', 7, 8, '9 fizz', '10 buzz', 11, '12 fizz', 13, 14, '15 fizzbuzz']

# %%
#Notification(not part for quiz but for sake of my memory)
#Stl Techweek
#April 13-17 2026
