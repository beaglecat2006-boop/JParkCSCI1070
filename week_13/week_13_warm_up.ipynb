# %%
sentence="consonants, words"
def stringsplit(sentence):
    sentlist = sentence.split(",")
    return sentlist
stringsplit(sentence)
# Out:
# ['consonants', ' words']

# %%
#Correct_Method

def extract_consonants_vowels(word):

    """
    This function will take in word and then count the numner of constants and the number of vowels
    """

consonants = 0
vowels=0

#clear list of vowels so it would not be redundant

for i in word
