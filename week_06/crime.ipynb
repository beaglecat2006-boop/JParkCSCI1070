# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
! pip3 install statsmodels

# %%
from crime_data.csv import KneighborsClassifier
from sklearn.model_selection import train_test_split
knn = NeighborsClassifier(n_neighbors=15)

KneighborsClassifier = pd.read_csv("diabetes.csv")
KneighborsClassifier.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from crime_data.csv import KneighborsClassifier
#       2 from sklearn.model_selection import train_test_split
#       3 knn = NeighborsClassifier(n_neighbors=15)
#
# ModuleNotFoundError: No module named 'crime_data'

# %%
#Expand which of 15 is closser to -- increasing to 15 instead of 11
