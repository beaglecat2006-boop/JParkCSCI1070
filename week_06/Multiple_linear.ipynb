# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime_df=pd.read_csv("Crime_data.csv")
crime_df.head()

# %%
y = crime_df['x1']
x = crime_df[['x2','x5']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y = crime_df['x1']
#       2 x = crime_df[['x2','x5']]
#
# NameError: name 'crime_df' is not defined

# %%
from sklearn.linear_model import ()LinearRegression
""Linear regression is a class and we are creating an instance (instantiationg) that class""(in bulk comment)

Regression = LinearRegression()
Regression.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1465, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1507, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1308, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1945, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# ...

# %%
y_pred = regression.predict(X_test)
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 y_pred = regression.predict(X_test)
#       2 y_pred
#
# NameError: name 'regression' is not defined

# %%
accuracy_score = regression.score(X_test, y_test)
accuracy_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 accuracy_score = regression.score(X_test, y_test)
#       2 accuracy_score
#
# NameError: name 'regression' is not defined

# %%
regression.coef_

# %%
#What is the equation for th model?
#X1= .37*x2 + 4.51*x5

# %%
# OLS Regression

OLS(Ordinary least squares regression)type of linear regression that lets uyou handle interactions kthat lets you hanbdle interactions as well as features taht dont have inbteractions with ols regressions yo can incoroporate features that are correlated with each other

# %%
! pip3 install statsmodels
# Out:
# 359.49s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 30.7 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [statsmodels] [statsmodels]
# ...

# %%
from statsmodels.formula.api import ols
diabetes_df = pd.read_csv("../week_06/diabetes.csv")
diabetes_df.head()

load diabetes.csv
# Out:
#   Cell In[12], line 5
#     load diabetes.csv
#          ^
# SyntaxError: invalid syntax

# %%
diabetes_df['outcome'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 diabetes_df['outcome'].value_counts()
#
# NameError: name 'diabetes_df' is not defined

# %%
diabetes_vs_insulin = ols("Outcome ~ insulin", data=diabetes_df).fit()
print(diabetes_vs_insulin.params)

# Outcome = .000540*insulin + .305844
# Numeric value and continuous--> This data base is not continuous(only predicts 0 and 1)
#Predicting Binary outcome
#OLS regression i(or any type of regressions) doesn't make sense to use for a binary outcomne problem (or # and any discrete outcome problem)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 diabetes_vs_insulin = ols("Outcome ~ insulin", data=diabetes_df).fit()
#
# NameError: name 'diabetes_df' is not defined

# %%
intercept,slope= diabestes_vs_insulin.params
sns.scatterplot(x='Insulin', 
                y='Outcome', 
                data=diabetes_df)

plot.axline(xy1=(0,intercept), slope=slope)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 intercept,slope= diabestes_vs_insulin.params
#       2 sns.scatterplot(x='Insulin',
#       3                 y='Outcome',
#       4                 data=diabetes_df)
#       6 plot.axline(xy1=(0,intercept), slope=slope)
#
# NameError: name 'diabestes_vs_insulin' is not defined

# %%
Legistic Regression=Binary outcome case
#The graph is not effective, and not close to the line at all(Bad model for use for this problem, in Binary outcome scenario)

# %%
#Ols works best when we have a gradient of coutomes(Make sure to change to bulk comment later) we're trying to predict, 
# BUT we can use logistic regression to predict binary outcomes. 
# These are just examples of how the code works but the outcomes are meaningless
# No interaction between two variables = low or no corrleation between the paramentes should be used to predict the outcome here

Example:
age_gl_no_int = ols('outcome ~ Age + Glucose' , data = diabetes_df).fit()
print(age_gl_no_int.params)
#Outcome = .00503*Age + .006473*glucose - .600748
# Out:
#   Cell In[16], line 6
#     Example:
#             ^
# SyntaxError: invalid syntax

# %%
#With interation - there is a corelation between the params
#Used to predict the outcome
age_gl_int = ols('outcome ~ Age*Glucose' , data = diabetes_df).fit()
print(age_gl_int.params)
    #Outcome= .014172*age + .008923*Glucose - .000072*Age*glucose - .905058(interaction)
