# %%
import numpy as np
import pandas as pd
import statistics 
csv_df = pd.read_csv("titanic.csv")

# %%
#Linear Regression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import statistics
import pandas as pd
csv_df = pd.read_csv("titanic.csv")

required_columns = ["Embarked","Survived"]

# %%
# !pip3 install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

titanic_df = pd.read_csv("titanic.csv")
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Explanation for the code I did
#Originally I have tried to use linear regression in order to determine if the passenger on the Titanic had survived or not,
since it helps predict the dependent variable. However, not only I have struggled the process after Pip installation,
I also noticed that this method might not be the right way to predict the survival(if they lived or died) in the Titanic,
considering survival is not a dependent variable. So I instead used supervised learning, as Seaborn is already installed, I could
use and code until I got my desired outcome. If the passenger has survived, the result turns out to be 1, and if they did not survive,
the result is 0.
