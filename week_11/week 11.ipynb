# %%
import pandas as pd
from sklearn import tree
from sklearn.metrics import confusion

# %%
from sklearn.model selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = diabetes_df.drop('outcome',axis= 1)
y= diabetes_df['outcome']

X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_split = 0.3
                                                    random_size = 
                                                    strati )


#standardize
sc=standardscaler()
X_test= sc.fit_transform(X_test)
X_train = sc.fit_transform

# %%
from sklearn.ensemble import RandomForestClassifier

#random forest is an aggregated decision tree

rf=RandomForestClassifier(n_estimators=100, random_state=50)
rf = rf.fit(X_train,y_train)
rf.score=(X_test, y_test)

# %%
ConfusionMatrixDisplay.from_estimator(rf,X_test, y_test)

# %%
#recall
51/(51+30)

# %%
import numpy as np

numbers=[5,10,15,20,25,30]
Average=sum(numbers)/6
print("The average is", Average)
# Out:
# The average is 17.5

# %%
import numpy as np 
numbers=[10,20,30,40,50]

def calculate_average(numbers):
    """  
    This function calculates the average
    """

total = 0
for number in numbers:
    total += number

return total

length =len(numbers)
average=total/length
return Average

average=calculate_average(numbers)


print("The average is:", average)
# Out:
#   Cell In[6], line 13
#     return total
#     ^
# SyntaxError: 'return' outside function

# %%
print(rf.feature_importances_, X.columns)

# %%
import matplotlib.pyplot as plt
rf_tree = rf.estimators_[4]
tree.plot_tree(rf_tree)
plt.savefig("rf_tree.svg")

# %%
# %pip install xgboost

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train,y_train)

y_pred = xgb.predict(X_test)
y_pred

# %%
ConfusionMatrixDisplay.from_estimator

# %%
#recall
48/(33+48)

# %%
from sklearn.metrics import roc_curve, roc_auc_score
#ROC = Receiving Operating Characterisitic roc_curve
#ROC curves summarize the tradeoff between true positives and false positives
#they are most appropriate for balanced dataset and can be overly optimistic fro severly imbalanced classification problems
#auc= area under the curve

fpr, tpr, thresholds = roc_curve(y_test,y_pred)
auc= roc_auc_score(y_test, y_pred)
print(fpr, tpr)

# %%
auc

# %%
plt.plot(fpr, tpr, marker = ".")
plt.xlabel("false positive rate")
plt.ylabel("true postive rate")

# %%
#precision_recall curves summarize the tradeoff between true positive rate and positive values
#These are ideal for all positive values + imbalanced dataset where one outcome is 10+x more likely than another

from sklearn.metrics import precision_recall_curve, fl_score, auc
precision, recall, thresholds = precision_recall_curve(y_train)
pr_auc = auc(recall, precision)
pr_auc

# %%
plt.plot(recall, precision, marker = ".")
plt.xlabel("Recall")
plt.ylabel("Precision")

# %%
#final projection= QNA section(yes, some question that are not complicated, short QnA)
#Unsupervised Learning Model= differ from Supervised Model(Self Supervised Learning model(most Ai))
