# %%
#1.How to Avoid Overfitting

1. Overfitting—model is way too complex and adepts over learning data too well(low training error but high test error)

Test error: New data set and does not have good results
Variants:One dataset it performs very well, on another dataset it performs very poorly
 

Therefore in order to avoid overfitting it is important to use  Example of Ensemble Method

For it works for Bias and Variance

Variance— how much your classifier changes if you train on a different set of data
Bias— inherent error that you get from your classification model want to minimize

Variance=results overfitting

Or Bagging

Bagging—>booststrap aggreaating

Bagging is a way to decrease the variance of the model by generating additional training data

#Train_test_split, Change Resampling Approach
#Avoid Making model too simple
#Proper Feature selection, Demensional reduction

# %%
#2. Wrtie a function that takes in a sentence and splits all values, seperated by commas into list elements
#Memorize, Function does not equal actual function

sentence="Mike, John, Sarah, Tom"
def stringsplit(sentence):
    sentlist = sentence.split(",")
    return sentlist
stringsplit(sentence)
# Out:
# ['Mike', ' John', ' Sarah', ' Tom']
