# %%
numbers = [10, 20, 30, 40, 50]

def calculate_average(numbers):
    """
    this function calculates the average
    """
    total = 0
    for number in numbers:
        total += number

    length = len(numbers)
    average = total/length
    return average

average =calculate_average(numbers)
print("The average is:", average)
# Out:
# The average is: 30.0

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt

crime_df = pd.read_csv("USArrests.csv")
crime_df.head()
# Out:
#         State  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
#clustering
from sklearn.cluster import KMeans

X=crime_df.drop('state', axis = 1)
y=crime_df['state']

plt.scatter(X['murder'], X['UrbanPop'])

#enumerating allows us to keep track of the indexes associated with each iteration
for i, txt in enumerate(y):
    plt.annotate(txt, (X['murder'][i], X['UrbanPop'][i]))

plt.xlabel('Murder')
plt.ylabel('Urban Population')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 4
#       1 #clustering
#       2 from sklearn.cluster import KMeans
# ----> 4 X=crime_df.drop('state', axis = 1)
#       5 y=crime_df['state']
#       7 plt.scatter(X['murder'], X['UrbanPop'])
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
# ...

# %%
inertias = []
distortions= []

for k in range(1,10):
    model = KMeans(n_clusters=k).fit(x)

#distortion is the avverage of the squared
#Distane from the cluster center
#To the data points(in Euclidean space)
#Euclidean space = standard 2+ dimensional space

distance = cdist(X, model.cluster_centers_, 'euclidean')

distortion = sum(np.min(distance, axis=1))/X.shape[0]
distortions.append(distortion)

#inertia is calculation by measuring
#the distance between each data point
#and the centroid and summing the square
#across the cluster. A good model is one
#with low inertia or distortion
#And a low number of clusters

inertia=model.inertia_
inertias.append(inertia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2 distortions= []
#       4 for k in range(1,10):
# ----> 5     model = KMeans(n_clusters=k).fit(x)
#       7 #distortion is the avverage of the squared
#       8 #Distane from the cluster center
#       9 #To the data points(in Euclidean space)
#      10 #Euclidean space = standard 2+ dimensional space
#      12 distance = cdist(X, model.cluster_centers_, 'euclidean')
#
# NameError: name 'x' is not defined

# %%
plt.plot(range(1,10), distortions)
#elbow.method(number of clusters)

# %%
plt.plot(range(1,10), distortions)
plt.title('elbow method inertia')

# %%
#Hierarchial

from scipy.cluster.hirearchy import dendogram, linkage
linked = linkage(X, 'ward')
plt.figure(figsize=(10,7))

dendro = dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 #Hierarchial
# ----> 3 from scipy.cluster.hirearchy import dendogram, linkage
#       4 linked = linkage(X, 'ward')
#       5 plt.figure(figsize=(10,7))
#
# ModuleNotFoundError: No module named 'scipy.cluster.hirearchy'

# %%
from sklearn.cluster import AgglomerativeClustering
#divides the population into several clusters so that the datapoints are in the same cluster
#as other data points are most similar to each other
#those in different clusters are more dissimlar

cluster = AgglomerativeClustering(n_clusters=3, linkage='ward')
cluster= cluster.fit_predict(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       2 #divides the population into several clusters so that the datapoints are in the same cluster
#       3 #as other data points are most similar to each other
#       4 #those in different clusters are more dissimlar
#       6 cluster = AgglomerativeClustering(n_clusters=3, linkage='ward')
# ----> 7 cluster= cluster.fit_predict(X)
#
# NameError: name 'X' is not defined

# %%
plt.figure(figsize=(10,10))
plt.scatter(X['Murder'], X['UrbanPop'], c=cluster.labels_)
for i, txt in enumerate(y):
    plt.annotate(txt, (X['Murder'][i], X['UrbanPop'][i]))

plt.xlabel('Murder')
plt.ylabel('UrbanPop')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.figure(figsize=(10,10))
#       2 plt.scatter(X['Murder'], X['UrbanPop'], c=cluster.labels_)
#       3 for i, txt in enumerate(y):
#
# NameError: name 'plt' is not defined

# %%
#DimensionalityReduction

from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split

diabetes_df = pd.read_csv("week_6_diabetes_data.csv")
diabetes_df.head()

# %%
X= diabetes_df.drop('outcome', axis=1)
y= diabetes_df['outcome']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state=50, stratify = y)

model=LogisticRegression(random_state=50).fit(X_train, y_train)

#predicted outcomes
predicted=model predict(X_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_prediction(y_test,predicted)

# %%
from sklearn.decomposition import TruncatedSVD
#singular value decomposition = factorization
#techinque for real or complex numbers in a matrix
#in short, it is untangling patterns in the numbers
#using matrix decomposition(linear algebra concept)
#truncatedSVD is typically used for sparse dataset
#this one isnt sparse and it unlike some other dimensionality reduction techniques
#doesnt produce the list of the features
#it is selecting because it is more abstract
#than that
svd = TruncatedSVD(n_components=6)
X_train_svd = svd.fit_transform(X_train)
X_test_svd=svd.fit_transform(X_test)

model=LogisticRegression(random_state=50).fit(X_train_svd,y_train)

model.score(X_test_svd, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#       2 #singular value decomposition = factorization
#       3 #techinque for real or complex numbers in a matrix
#       4 #in short, it is untangling patterns in the numbers
#    (...)      9 #it is selecting because it is more abstract
#      10 #than that
#      11 svd = TruncatedSVD(n_components=6)
# ---> 12 X_train_svd = svd.fit_transform(X_train)
#      13 X_test_svd=svd.fit_transform(X_test)
#      15 model=LogisticRegression(random_state=50).fit(X_train_svd,y_train)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.matrics import ConfusionMatrixDisplay
ConfusionMatrixDispla.from_estimator(model, X_test_svd,y_test)
