# %%
#Warm up

1.A Linear Regression is a prediction of dependent variable from one independent variable 

2.K nearest neighbor is used to predict a group of a datapoint based on majority votes for nearest neighbors

# %%
#for multiple linear regression and other models

# %%
#to understand if your data set is imbakanced:
#look at the value counts for the outcome
diabetes.df['outcome'].value_counts()

#use over or undersampling(but has grey area)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #to understand if your data set is imbakanced:
#       2 #look at the value counts for the outcome
# ----> 3 diabetes.df['outcome'].value_counts()
#
# NameError: name 'diabetes' is not defined

# %%
from sklearn.linear_model
from sklearn.model_section import train_test_split

x= diabetes.df.drop('outcome',axis=1)
y= diabetes.df['outcome']

x_train,x_test,y_train,y_test = train_test_split 
                                x,y, test_size=0.3
                                random_state=42

# %%
# %pip install imblearn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [imblearn]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#resample our training data with RandomOverSampler(Naive approach)
from imblearn.over_sampling import RandomOverSampler
ros=RandomOverSampler(random_state=42)

x_resampled, y_resampled = ros.fit_resample(x_train,y_train)
#train the model using resample data
model = LogisticRegression(random_state=42)
model.fit(x_resampled,y_resampled)

# %%
y_pred = model.predict(x_test)
#Create new value in dataframe to predict new value

from sklearn.metrics import classification_import

# %%
#Recall= most important on medical 
#what is our recall
#tp/tp+fn

true positive=58

false negative=23

58/(58+27)

# %%
#Accuracy+Precision=tuning for model, on data set

# %%
#Undersampling
#ClusterCentroids uses Kmeans to reduce the number of samples
from imblearn.under_sampling import ClusterCentroids

rus = ClusterCentroids(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X_train,y_train)

# %%
model = LogisticRegression(random_state=42)
model.fit(X_resampled,y_resampled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = LogisticRegression(random_state=42)
#       2 model.fit(X_resampled,y_resampled)
#
# NameError: name 'LogisticRegression' is not defined

# %%
y_pred = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 y_pred = model.predict(x_test)
#
# NameError: name 'model' is not defined

# %%
Confusion matrix
#What are our recall?
55/(55+26)

# %%
Decision_tree

Resource:Support Vector machine

Has Feathers? -->true(can fly), false(has finns)
->
# Out:
#   Cell In[7], line 3
#     Resource:Support Vector machine
#                      ^
# SyntaxError: invalid syntax
